# %% [markdown]
# <a href="https://colab.research.google.com/github/VHDRKL/1031/blob/main/F0706021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris = load_iris()
import pandas as pd
X = pd.DataFrame(data = iris.data, columns = iris.feature_names)
y = pd.DataFrame(data=iris.target, columns = ['irisType'])
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train = X_train.values
X_test  = X_test.values
import tensorflow as tf
y_train = tf.keras.utils.to_categorical(y_train)
y_test  = tf.keras.utils.to_categorical(y_test)

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
model1 = Sequential()
model1.add( Dense ( 64, activation = 'relu', input_shape= X_train[0].shape))
model1.add( Dense (128, activation = 'relu'))
model1.add( Dense (128, activation = 'relu'))
model1.add( Dense (128, activation = 'relu'))
model1.add( Dense (128, activation = 'relu'))
model1.add( Dense ( 64, activation = 'relu'))
model1.add( Dense ( 64, activation = 'relu'))
model1.add( Dense ( 64, activation = 'relu'))
model1.add( Dense ( 64, activation = 'relu'))
model1.add( Dense (  3, activation = 'softmax'))
print(model1.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 64)                320
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# _________________________________________________________________
# ...

# %%
model1.compile(optimizer='adam', loss= 'categorical_crossentropy', metrics = ['acc'])
H = model1.fit(X_train, y_train, batch_size = 32,
         epochs=100, validation_split = 0.1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 58ms/step - loss: 1.0939 - acc: 0.3519 - val_loss: 1.0520 - val_acc: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0378 - acc: 0.5093 - val_loss: 0.9920 - val_acc: 0.6667
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9497 - acc: 0.6481 - val_loss: 0.8789 - val_acc: 0.6667
# Epoch 4/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8121 - acc: 0.6944 - val_loss: 0.7181 - val_acc: 0.8333
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6203 - acc: 0.7963 - val_loss: 0.5030 - val_acc: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4003 - acc: 0.9722 - val_loss: 0.3391 - val_acc: 0.9167
# Epoch 7/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2435 - acc: 0.9537 - val_loss: 0.5123 - val_acc: 0.7500
# Epoch 8/100
# ...

# %%
print(model1.evaluate(X_test, y_test))  # output=(loss, accuracy)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1483 - acc: 0.9333
# [0.14833055436611176, 0.9333333373069763]
